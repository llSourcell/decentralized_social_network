# %% [markdown]
# ## Demo - Running a simple SteemConnect web app to access the STEEM social network blockchain
#
# ## Examples of Decentralized Social Networks
#
# #### Sapien (sapien.network),
#
# ![alt text](https://steemitimages.com/DQmPBqZkAXCcmWZdxgAtENSL35qyiogvHaoZRNLVV8wGrbb/sapien%20netwrkkk.PNG "Logo Title Text 1")
#
# - A highly customizable, democratized social news platform built on the Ethereum blockchain
# - Aims to reinvent social from the ground up
# - Mission is to "to champion users and truth, not financial gain, as the core of its social network.”
# - Aims to reward “millions of content creators and curators without any centralized intermediaries.”
# - Transparency and accuracy are important to its founders
#
# #### Sola (sola.ai) hybrid of media and social network governed by AI altogether with users.
#
# ![alt text](https://blog.coinspectator.com/wp-content/uploads/2017/11/sola2.png "Logo Title Text 1")
#
# - 700,000 users worldwide, has evolved from what it calls “the concept of following.”
# - Applies AI algorithms combined with users reactions to spread quality content
# - Action Points are converted into to SOL tokens.
# - SOL allows them to share revenue from advertising, user payments, and partnerships with users, providing a strong financial incentive to use our service and create quality content
# - Allows every user to participate and make money, not just the known entertainers and influencers
#
# ####  Indorse (indorse.io) is a LinkedIn-like decentralized platform based on the Ethereum blockchain.
#
# ![alt text](https://steemitimages.com/0x0/https://s2.postimg.org/ir7l1rn15/tabel_1_indorse.png "Logo Title Text 1")
#
# - Uses different methods to validate skills in a simple and objective way, including decentralized consensus, where examples of skill are judged anonymously by random other users.
# - Indorse verifies and validates user claims, and rewards users for endorsing the skill sets of others
# - If someone is an expert in NodeJS, they put up a claim and attach proof such as their GitHub repos
# - Other members in the same domain on Indorse verify it. Based on the consensus, the claim is either ‘indorsed’ or flagged.”
# - users are rewarded for their activity on the platform with IND tokens. These tokens can later be traded or used on the platform to purchase services like advertising, or company pages with validated connections.
#
# #### onG.social (ong.social) is a blockchain-based social dashboard that provides ease of control for both central-decentralized social media networks and that also supports community building and social interaction with cryptocurrency rewards. It runs on two blockchains, Ethereum and Wavesplatform.
#
# ![alt text](https://ong.social/templates/ong/images/about/statistics.png "Logo Title Text 1")
#
# - brings all social networks of an individual to one place
# - an individual’s content can be distributed to all of their networks through the onG network at the same time.
# - onG goes a step further by monetizing the efforts of participants within the network
# - Posts are also validated by measuring the global impact of a submission and verified truth through community consensus, a system that — they say — motivate the public to generate more quality content in order to eliminate fake news.
#
# ## Architecture
#
# ![alt text](https://steemitimages.com/0x0/http://dragosroua.com/wp-content/uploads/2017/01/Blockchain-as-a-Social-Network-Page-1.png "Logo Title Text 1")
#
# - Steemit seems like the biggest blockchain based social network at the moment
# - developers built Steemit on a whole new blockchain instead of using Ethereum.
# - Ethereum could bring many benefits to a decentralized social network
# - i.e it would benefit from the network effects of Ethereum, it would benefit from all of the scaling improvements that the Ethereum team is working on.
#
# #### Currencies
# - There are three currencies in your Steemit wallet; Steem, Steem Power and Steem Dollars.
#
# ![alt text](https://steemitimages.com/0x0/https://res.cloudinary.com/hpiynhbhq/image/upload/v1517537146/zslzkgxqzfgohqqzwzbf.jpg "Logo Title Text 1")
#
# ###### STEEM
# - Steemit is based on Steem blockchain (like Bitcoin has its own blockchain).
# - It can be powered up into Steem Power, traded for Steem Dollars, and transferred to other accounts.
#
# ######  STEEM POWER (SP)
# - It is Steem that is vested into the platform and does not remain liquid (immediately trade-able) once vested.
# - It is the standard measurement of how much influence a user has in the Steem network.
# - The more Steem Power a user holds, the more they can influence the value of posts and comments they upvote
#
# ###### STEEM DOLLAR (SBD)
#
# - It isl liquid, stable-value currency tokens designed to be pegged to 1 USD
# - SBD is basically a token value of which is deigned to remain equal to one USD of Steem value (explained later).
# - Steem Dollars can be traded with Steem, and transferred to other accounts for commerce or exchange.
#
# #### Consensus
#
# ![alt text](https://steemitimages.com/DQmaFSQxLDiCsSitWj7ouojRRUFAga3HjcMHWQ7PitLoL3w/Steem%20proof%20of%20brain%20mining.png "Logo Title Text 1")
#
# - Steem is earned through Proof of Brain (two ways to earn)
# - Author Rewards: When you publish a post or a comment and other users upvote it, you earn author rewards.
# - Curation Rewards: When another author publishes a post you get rewarded a share of the value of your upvote as curation reward.
# - Steem blockchain stores content + currency.
# - All the content published on Steemit is permanently stored on the blockchain.
# - It is immutable, meaning you cannot delete it from the blockchain, even if you delete it from the website.
# - Whenever you create or upvote content, you actually are doing a transaction on the Steem blockchain and that transaction is permanently stored.
# - The immutability means total freedom from censorship.
# - The upvote system means decentralization and power in your hands.
# - Proof of Brain means you can mine Steem with your brain
# - Steem is not mined. It was mine-able initially but the mining was stopped by Steemit Inc.
# - All the Steem in circulation or supply is premined except a small percentage which is created annually through inflation
